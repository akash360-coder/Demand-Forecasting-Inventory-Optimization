# %% [markdown]
# # Model training
#
# Train a demand forecasting model using generated sales features.

# %%
from src.demand_intelligence.data_generation import ensure_dataset
from src.demand_intelligence.forecasting import compute_model_metrics
df = ensure_dataset()
print(compute_model_metrics(df))
