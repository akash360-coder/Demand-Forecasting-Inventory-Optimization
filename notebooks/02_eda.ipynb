# %% [markdown]
# # EDA
#
# This notebook highlights summary statistics, seasonality, and demand patterns.

# %%
from src.demand_intelligence.data_generation import ensure_dataset
df = ensure_dataset()
print(df.groupby('region')['units_sold'].mean())
