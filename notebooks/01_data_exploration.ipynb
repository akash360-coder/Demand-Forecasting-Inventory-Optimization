# %% [markdown]
# # Data exploration
#
# This notebook shows how the synthetic retail dataset is loaded and inspected before forecasting.

# %%
from src.demand_intelligence.data_generation import ensure_dataset
df = ensure_dataset()
print(df.head())
